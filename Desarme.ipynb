# %%
import pandas as pd

# %%
 pem = pd.read_excel('PEMNPEMDETALHADOMAIO.xlsx', {"Referencia", "Causa" = "Vegetação"})
print(pem)    
print(len(pem), index)
# Out:
#       Referencia Grupo                         Causa Depto        Conjunto  \
# 0     BA01984960   TER                       PÁSSARO    PS  ANGRA DOS REIS
# 1     BA01988240   PEM           DEGRADAÇÃO MATERIAL    PL        ARARUAMA
# 2     BA01986246   PEM           DEGRADAÇÃO MATERIAL    PS       MAMBUCABA
# 3     BA01990878   PEM           DEGRADAÇÃO MATERIAL    PA   VAL DE PALMAS
# 4     0017362965   PRO         PROGRAMADA MANUTENÇÃO    PC     SANTA CLARA
# ...          ...   ...                           ...   ...             ...
# 9381  0017470949   PEM              CONDUTOR PARTIDO    PS  RETIRO SAUDOSO
# 9382  0017445113   PEM  MEDIDOR QUEIMADO SUBSTITUÍDO    PS        ITATIAIA
# 9383  0017489417   PEM  MEDIDOR QUEIMADO SUBSTITUÍDO    PS  RETIRO SAUDOSO
# 9384  0017404337   PRO              PROGRAMADA OBRAS    PS        ITATIAIA
# 9385  0017460429   PEM   DEFEITO EM RAMAL DE LIGAÇÃO    PS        ITATIAIA
#
# ...

# %%
 pem = pd.read_excel('PEMNPEMDETALHADOMAIO.xlsx')
 pem.head()
# Out:
#    Referencia Grupo                  Causa Depto        Conjunto Alimentador  \
# 0  BA01984960   TER                PÁSSARO    PS  ANGRA DOS REIS       ANG08
# 1  BA01988240   PEM    DEGRADAÇÃO MATERIAL    PL        ARARUAMA       ARA03
# 2  BA01986246   PEM    DEGRADAÇÃO MATERIAL    PS       MAMBUCABA       MAM02
# 3  BA01990878   PEM    DEGRADAÇÃO MATERIAL    PA   VAL DE PALMAS       VPA02
# 4  0017362965   PRO  PROGRAMADA MANUTENÇÃO    PC     SANTA CLARA       SCL03
#
#    Cli.CJ  Cli.SE  Cli.Alim   Cli x Tmp  ...  Fec AL Dec Coe Fec Coe  NT  \
# 0       1   42735      4130  2352.47000  ...  0.6208  0.0009  0.0010  MT
# 1       1   25950      5268  1630.93335  ...  0.2430  0.0006  0.0005  MT
# 2       1   15213      2605    24.81582  ...  0.1179  0.0000  0.0001  MT
# 3       1   27048      6393   275.27582  ...  0.2141  0.0001  0.0005  MT
# 4       1   11823      2132     3.37278  ...  0.0009  0.0000  0.0000  MT
#
# ...

# %%
pem = (len(columns = {'Referencia','Causa':'Vegetação'}))
# Out:
#   File "<ipython-input-57-15575da43331>", line 1
#     pem = (len(columns = {'Referencia','Causa':'Vegetação'}))
#                                               ^
# SyntaxError: invalid syntax
